# %%
import requests
import random
import json

base_url = "http://127.0.0.1:8081"
keycloak_url = "http://localhost:8080"

resp = requests.get(base_url)
assert resp.status_code == 404
assert resp.json()["status"] == 404
assert resp.json()["error"] == "Not Found"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[76], line 9
#       6 keycloak_url = "http://localhost:8080"
#       8 resp = requests.get(base_url)
# ----> 9 assert resp.status_code == 404
#      10 assert resp.json()["status"] == 404
#      11 assert resp.json()["error"] == "Not Found"
#
# AssertionError:

# %%
def getToken():
    headers = {
        'content-type': 'application/x-www-form-urlencoded',
    }

    data = {
      'client_id': 'registry-frontend',
      'grant_type': 'password',
      'username':'Kumarpawans67@gmail.com',
      'password':'123456'
    }

    response = requests.post('%s/auth/realms/sunbird-rc/protocol/openid-connect/token'%(keycloak_url), headers=headers, data=data)
    print(response.json())
    print(response.status_code)
    token = response.json()["access_token"]
    print(token)
    return token

# %%
token=getToken()
# Out:
# {'access_token': 'eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJGZHl5YkhKcHB0bTdMNnJ5d2Npd2Rlb1hsYktTVVcwY0NNYU5lRHAtZlZrIn0.....DZT1GZUkyGlWfV_f-mMdpZ0ySNT9DhIhTWmx6NvVJnV3SIJJeWSIv14_ECdwOMii3WWr_FOl-Y2RUpVUoprbocA_s6409gIMT-jUJ1evqKDtxAsBzlcY9QaEz3CrVSPJzU6sFHKIZj1_iUu451OFpgJmaBXRNOvrx64-EBF-bSu4EQ2Y-R4vpDGwR9jPEQ2G2e6uYm9ERq0a91VKfLSWPh-YotbQuwtrpfoNc8aIk2hUaa4BYAVo61WMdzI_TX4bLhrFNSGKGrX01-vF5-RCMusY6Q8SxpmFtm2xVQlY_jDpyjJJ9p1hdbBTGDuZYh79swrn6RRNuGlsjqNt4OP5cg', 'expires_in': 600, 'refresh_expires_in': 0, 'token_type': 'Bearer', 'not-before-policy': 1607576887, 'session_state': '806e0919-980f-4ba9-8314-7991a8bf9556', 'scope': 'profile email'}
# 200
# ...

# %%
headers = {
    'content-type': 'application/json',
    'Authorization': 'Bearer %s'%token, 
}

# %%
singledata = {
    "name":"GURIYA K", 
    "fatherName":"S M Arya",
    "motherName":"S M Arya",
    "grades": "a",
    "rollNumber": "2224300009",
    "dob": "1998-09-20",
    "gender": "F",
    "mobile": "9087363655",
    "email": "kumarpawans@gmail.com",
    "qualification":"DIPLOMA IN GENERAL NURSING and MIDWIFERY",
    "enrollmentNumber":"2210254300051",
    "examYear":"2022",
        "dated": "1922-12-29",
    "barCode": "123456",
    "credType":"Registration",
    "yearsOfTheCourse":[{
        "courseYear":"First Year",
        "examYear":"2020",
        "examMonth":"March",
        "result":"PASS",
        "totalMarksObtained":"426",
        "totalMarksObtainedInWord":"Four hundred and Twenty Six",
        "maxTotal":"400/500",
    "subject":[{"name":"COMMUNITY HEALTH NURSING","max-ext":"75","max-int":"25","obt-ext":"46","obt-int":"20","total":"66"},
    {"name":"HEALTH PROMOTION","max-ext":"75","max-int":"25","obt-ext":"40","obt-int":"19","total":"59"}]
    },
    {
        "courseYear":"Second Year",
        "examYear":"2021",
        "examMonth":"March",
        "result":"PASS",
        "totalMarksObtained":"426",
        "totalMarksObtainedInWord":"Four hundred and Twenty Six",
        "maxTotal":"500",
    "subject":[{"name":"COMMUNITY HEALTH NURSING","max-ext":"75","max-int":"25","obt-ext":"46","obt-int":"20"},
    {"name":"HEALTH PROMOTION","max-ext":"75","max-int":"25","obt-ext":"40","obt-int":"19"}]
    },
    {
        "courseYear":"Final Year",
        "examYear":"2022",
        "examMonth":"March",
        "result":"PASS",
        "totalMarksObtained":"426",
        "totalMarksObtainedInWord":"Four hundred and Twenty Six",
        "maxTotal":"500",
    "subject":[{"name":"COMMUNITY HEALTH NURSING","max-ext":"75","max-int":"25","obt-ext":"46","obt-int":"20"},
    {"name":"HEALTH PROMOTION","max-ext":"75","max-int":"25","obt-ext":"40","obt-int":"19"}]
    }]

}

# %%
manydata = [
    {"name":"GURIYA K3", 
    "father":"FFF",
    "mother":"MMMM",
    "grades": "B",
    "rollNumber": "2224300003",
    "dob": "1998-09-20",
    "gender": "F",
    "mobile": "9087363657",
    "email": "kumarpawans2@gmail.com",
    "qualification":"DIPLOMA IN GENERAL NURSING and MIDWIFERY",
    "enrollmentNumber":"2210254300051",
    "examYear":"2022",
    "yearsOfTheCourse":[{
        "courseYear":"First Year",
        "examYear":"2022",
        "examMonth":"March",
        "result":"result",
        "totalMarksObtained":"426",
        "totalMarksObtainedInWord":"Four hundred and Twenty Six",
        "maxTotal":"500",
    "subjects":[{"name":"COMMUNITY HEALTH NURSING","max-ext":"75","max-int":"25","obt-ext":"46","obt-ext":"20"},

    {"name":"HEALTH PROMOTION","max-ext":"75","max-int":"25","obt-ext":"40","obt-ext":"19"}]
    }]},
    {
    "name":"GURIYA K4", 
    "father":"FFF",
    "mother":"MMMM",
    "grades": "B",
    "rollNumber": "2224300004",
    "dob": "1998-09-20",
    "gender": "F",
    "mobile": "9087363658",
    "email": "kumarpawans1@gmail.com",
    "qualification":"DIPLOMA IN GENERAL NURSING and MIDWIFERY",
    "enrollmentNumber":"2210254300051",
    "examYear":"2022",
    "yearsOfTheCourse":[{
        "courseYear":"First Year",
        "examYear":"2022",
        "examMonth":"March",
        "result":"result",
        "totalMarksObtained":"426",
        "totalMarksObtainedInWord":"Four hundred and Twenty Six",
        "maxTotal":"500",
    "subjects":[{"name":"COMMUNITY HEALTH NURSING","max-ext":"75","max-int":"25","obt-ext":"46","obt-ext":"20"},
    {"name":"HEALTH PROMOTION","max-ext":"75","max-int":"25","obt-ext":"40","obt-ext":"19"}]
    }]

},
    {
    "name":"GURIYA K4", 
    "father":"FFF",
    "mother":"MMMM",
    "grades": "B",
    "rollNumber": "2224300004",
    "dob": "1998-09-20",
    "gender": "F",
    "mobile": "9087363658",
    "email": "kumarpawans1@gmail.com",
    "qualification":"DIPLOMA IN GENERAL NURSING and MIDWIFERY",
    "enrollmentNumber":"2210254300051",
    "examYear":"2022",
    "yearsOfTheCourse":[{
        "courseYear":"First Year",
        "examYear":"2022",
        "examMonth":"March",
        "result":"result",
        "totalMarksObtained":"426",
        "totalMarksObtainedInWord":"Four hundred and Twenty Six",
        "maxTotal":"500",
    "subjects":[{"name":"COMMUNITY HEALTH NURSING","max-ext":"75","max-int":"25","obt-ext":"46","obt-ext":"20"},
    {"name":"HEALTH PROMOTION","max-ext":"75","max-int":"25","obt-ext":"40","obt-ext":"19"}]
    }]

},
    {
    "name":"GURIYA K4", 
    "father":"FFF",
    "mother":"MMMM",
    "grades": "B",
    "rollNumber": "2224300004",
    "dob": "1998-09-20",
    "gender": "F",
    "mobile": "9087363658",
    "email": "kumarpawans1@gmail.com",
    "qualification":"DIPLOMA IN GENERAL NURSING and MIDWIFERY",
    "enrollmentNumber":"2210254300051",
    "examYear":"2022",
    "yearsOfTheCourse":[{
        "courseYear":"First Year",
        "examYear":"2022",
        "examMonth":"March",
        "result":"result",
        "totalMarksObtained":"426",
        "totalMarksObtainedInWord":"Four hundred and Twenty Six",
        "maxTotal":"500",
    "subjects":[{"name":"COMMUNITY HEALTH NURSING","max-ext":"75","max-int":"25","obt-ext":"46","obt-ext":"20"},
    {"name":"HEALTH PROMOTION","max-ext":"75","max-int":"25","obt-ext":"40","obt-ext":"19"}]
    }]

},
    {
    "name":"GURIYA K4", 
    "father":"FFF",
    "mother":"MMMM",
    "grades": "B",
    "rollNumber": "2224300004",
    "dob": "1998-09-20",
    "gender": "F",
    "mobile": "9087363658",
    "email": "kumarpawans1@gmail.com",
    "qualification":"DIPLOMA IN GENERAL NURSING and MIDWIFERY",
    "enrollmentNumber":"2210254300051",
    "examYear":"2022",
    "yearsOfTheCourse":[{
        "courseYear":"First Year",
        "examYear":"2022",
        "examMonth":"March",
        "result":"result",
        "totalMarksObtained":"426",
        "totalMarksObtainedInWord":"Four hundred and Twenty Six",
        "maxTotal":"500",
    "subjects":[{"name":"COMMUNITY HEALTH NURSING","max-ext":"75","max-int":"25","obt-ext":"46","obt-ext":"20"},
    {"name":"HEALTH PROMOTION","max-ext":"75","max-int":"25","obt-ext":"40","obt-ext":"19"}]
    }]

},
    {
    "name":"GURIYA K4", 
    "father":"FFF",
    "mother":"MMMM",
    "grades": "B",
    "rollNumber": "2224300004",
    "dob": "1998-09-20",
    "gender": "F",
    "mobile": "9087363658",
    "email": "kumarpawans1@gmail.com",
    "qualification":"DIPLOMA IN GENERAL NURSING and MIDWIFERY",
    "enrollmentNumber":"2210254300051",
    "examYear":"2022",
    "yearsOfTheCourse":[{
        "courseYear":"First Year",
        "examYear":"2022",
        "examMonth":"March",
        "result":"result",
        "totalMarksObtained":"426",
        "totalMarksObtainedInWord":"Four hundred and Twenty Six",
        "maxTotal":"500",
    "subjects":[{"name":"COMMUNITY HEALTH NURSING","max-ext":"75","max-int":"25","obt-ext":"46","obt-ext":"20"},
    {"name":"HEALTH PROMOTION","max-ext":"75","max-int":"25","obt-ext":"40","obt-ext":"19"}]
    }]

},
    {
    "name":"GURIYA K4", 
    "father":"FFF",
    "mother":"MMMM",
    "grades": "B",
    "rollNumber": "2224300004",
    "dob": "1998-09-20",
    "gender": "F",
    "mobile": "9087363658",
    "email": "kumarpawans1@gmail.com",
    "qualification":"DIPLOMA IN GENERAL NURSING and MIDWIFERY",
    "enrollmentNumber":"2210254300051",
    "examYear":"2022",
    "yearsOfTheCourse":[{
        "courseYear":"First Year",
        "examYear":"2022",
        "examMonth":"March",
        "result":"result",
        "totalMarksObtained":"426",
        "totalMarksObtainedInWord":"Four hundred and Twenty Six",
        "maxTotal":"500",
    "subjects":[{"name":"COMMUNITY HEALTH NURSING","max-ext":"75","max-int":"25","obt-ext":"46","obt-ext":"20"},
    {"name":"HEALTH PROMOTION","max-ext":"75","max-int":"25","obt-ext":"40","obt-ext":"19"}]
    }]

},
    {
    "name":"GURIYA K4", 
    "father":"FFF",
    "mother":"MMMM",
    "grades": "B",
    "rollNumber": "2224300004",
    "dob": "1998-09-20",
    "gender": "F",
    "mobile": "9087363658",
    "email": "kumarpawans1@gmail.com",
    "qualification":"DIPLOMA IN GENERAL NURSING and MIDWIFERY",
    "enrollmentNumber":"2210254300051",
    "examYear":"2022",
    "yearsOfTheCourse":[{
        "courseYear":"First Year",
        "examYear":"2022",
        "examMonth":"March",
        "result":"result",
        "totalMarksObtained":"426",
        "totalMarksObtainedInWord":"Four hundred and Twenty Six",
        "maxTotal":"500",
    "subjects":[{"name":"COMMUNITY HEALTH NURSING","max-ext":"75","max-int":"25","obt-ext":"46","obt-ext":"20"},
    {"name":"HEALTH PROMOTION","max-ext":"75","max-int":"25","obt-ext":"40","obt-ext":"19"}]
    }]

},
    {
    "name":"GURIYA K4", 
    "father":"FFF",
    "mother":"MMMM",
    "grades": "B",
    "rollNumber": "2224300004",
    "dob": "1998-09-20",
    "gender": "F",
    "mobile": "9087363658",
    "email": "kumarpawans1@gmail.com",
    "qualification":"DIPLOMA IN GENERAL NURSING and MIDWIFERY",
    "enrollmentNumber":"2210254300051",
    "examYear":"2022",
    "barCode":"12345",
    "yearsOfTheCourse":[{
        "courseYear":"First Year",
        "examYear":"2022",
        "examMonth":"March",
        "result":"result",
        "totalMarksObtained":"426",
        "totalMarksObtainedInWord":"Four hundred and Twenty Six",
        "maxTotal":"500",
    "subjects":[{"name":"COMMUNITY HEALTH NURSING","max-ext":"75","max-int":"25","obt-ext":"46","obt-ext":"20"},
    {"name":"HEALTH PROMOTION","max-ext":"75","max-int":"25","obt-ext":"40","obt-ext":"19"}]
    }]

},
    {
    "name":"GURIYA K4", 
    "father":"FFF",
    "mother":"MMMM",
    "grades": "B",
    "rollNumber": "2224300004",
    "dob": "1998-09-20",
    "gender": "F",
    "mobile": "9087363658",
    "email": "kumarpawans1@gmail.com",
    "qualification":"DIPLOMA IN GENERAL NURSING and MIDWIFERY",
    "enrollmentNumber":"2210254300051",
    "examYear":"2022",
    "yearsOfTheCourse":[{
        "courseYear":"First Year",
        "examYear":"2022",
        "examMonth":"March",
        "result":"result",
        "totalMarksObtained":"426",
        "totalMarksObtainedInWord":"Four hundred and Twenty Six",
        "maxTotal":"500",
    "subjects":[{"name":"COMMUNITY HEALTH NURSING","max-ext":"75","max-int":"25","obt-ext":"46","obt-ext":"20"},
    {"name":"HEALTH PROMOTION","max-ext":"75","max-int":"25","obt-ext":"40","obt-ext":"19"}]
    }]

},
    {
    "name":"GURIYA K4", 
    "father":"FFF",
    "mother":"MMMM",
    "grades": "B",
    "rollNumber": "2224300004",
    "dob": "1998-09-20",
    "gender": "F",
    "mobile": "9087363658",
    "email": "kumarpawans1@gmail.com",
    "qualification":"DIPLOMA IN GENERAL NURSING and MIDWIFERY",
    "enrollmentNumber":"2210254300051",
    "examYear":"2022",
    "yearsOfTheCourse":[{
        "courseYear":"First Year",
        "examYear":"2022",
        "examMonth":"March",
        "result":"result",
        "totalMarksObtained":"426",
        "totalMarksObtainedInWord":"Four hundred and Twenty Six",
        "maxTotal":"500",
    "subjects":[{"name":"COMMUNITY HEALTH NURSING","max-ext":"75","max-int":"25","obt-ext":"46","obt-ext":"20"},
    {"name":"HEALTH PROMOTION","max-ext":"75","max-int":"25","obt-ext":"40","obt-ext":"19"}]
    }]

}

]

# %%
userId =str(random.randint(1e10,1e11))



resp = requests.post("%s%s"%(base_url, '/api/v1/StudentMarksSheet'), headers=headers, json=singledata)
print(resp)
#assert resp.status_code == 200 or print (resp.json())
#idx = resp.json()["result"][entity_name]["osid"]
# Out:
# <Response [200]>

# %%
resp.json()
# Out:
# {'id': 'sunbird-rc.registry.create',
#  'ver': '1.0',
#  'ets': 1689332748189,
#  'params': {'resmsgid': '',
#   'msgid': '0c63eab4-587c-4a52-92c4-639115d60888',
#   'err': '',
#   'status': 'SUCCESSFUL',
#   'errmsg': ''},
#  'responseCode': 'OK',
#  'result': {'StudentMarksSheet': {'osid': '1-cc9e26ea-bb35-4c3d-a975-449a950d1216'}}}

# %%
print(resp.json())
resp.status_code, userId
# Out:
# {'id': 'sunbird-rc.registry.create', 'ver': '1.0', 'ets': 1689332748189, 'params': {'resmsgid': '', 'msgid': '0c63eab4-587c-4a52-92c4-639115d60888', 'err': '', 'status': 'SUCCESSFUL', 'errmsg': ''}, 'responseCode': 'OK', 'result': {'StudentMarksSheet': {'osid': '1-cc9e26ea-bb35-4c3d-a975-449a950d1216'}}}
# (200, '29470860447')

# %% [markdown]
# # generate certificate

# %%
# idx="1-ae00e88f-61c3-4d39-820d-920ac257de9e"
# resp = requests.get("%s/api/v2/%s/%s"%(base_url, "StudentMarksSheet", idx), headers={"Accept":"application/pdf", 'Authorization': 'Bearer %s'%token, "template": "https://raw.githubusercontent.com/kumarpawantarento/templates/main/nursingANM.html"})
# resp.status_code, resp.content
# print (resp.content)

# %% [markdown]
# # delete certificate

# %%
# esp = requests.delete("%s/api/v1/%s/%s"%(base_url, entity_name, idx), headers={"Accept":"application/json"})
# print(resp.status_code)
# assert resp.status_code == 200
# resp = requests.get("%s/api/v1/%s/%s"%(base_url, entity_name, idx), headers={"Accept":"application/json"})
# print(json.dumps(resp.json()))
# assert resp.json()["params"]["errmsg"] == "entity status is inactive"
