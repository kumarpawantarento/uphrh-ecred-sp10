# %%
import requests
import random
import json

base_url = "http://127.0.0.1:8081"
keycloak_url = "http://localhost:8080"

resp = requests.get(base_url)
assert resp.status_code == 404
assert resp.json()["status"] == 404
assert resp.json()["error"] == "Not Found"

# %%
def getToken():
    headers = {
        'content-type': 'application/x-www-form-urlencoded',
    }

    data = {
      'client_id': 'registry-frontend',
      'grant_type': 'password',
      'username':'Kumarpawans67@gmail.com',
      'password':'123456'
    }

    response = requests.post('%s/auth/realms/sunbird-rc/protocol/openid-connect/token'%(keycloak_url), headers=headers, data=data)
    print(response.json())
    print(response.status_code)
    token = response.json()["access_token"]
    print(token)
    return token

# %%
token=getToken()
# Out:
# {'access_token': 'eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJGZHl5YkhKcHB0bTdMNnJ5d2Npd2Rlb1hsYktTVVcwY0NNYU5lRHAtZlZrIn0.....g4GRNPYvdaFEWyO_vsyUAeQQOkj7REKnN9587g6gCSOsHnF71aYllq5BJ3aV3G7e1dgnNPYyH_fpNuWyu31ICvNe96W3qXXintAsDjLwgvc1ghWchJzOK_vyCdhAh1HJATMMIhNNKedPAQtnmgP8itYfngfqJpctn_lPO58LRZJjfXx5gV6_vxmw4ZEYJ66yYHazJe3v9eHz_PglPfy-IaMsORqacYtfTrVMrga7xJ4JoegmznwamteimPd9KrtNg8ha39yIzAnR4mQZGGQ9VjW9rYe4LAzAUv4EH8rMtGHz9ZwoR90mag0dp5rmlNoMRG6bqI93KF0_m7js1ap6Gg', 'expires_in': 600, 'refresh_expires_in': 600, 'refresh_token': 'eyJhbGciOiJIUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICI1OTFiZmY4YS1kNDdhLTQ1NzgtOWIyNS0xNWY4ZTNmYmQzYzUifQ.....fk0tYefj0TmBcslS7RQLX_8KIf4JLil213PvaEU0vzc', 'token_type': 'Bearer', 'not-before-policy': 1607576887, 'session_state': '21eff24b-495b-4d76-9c65-f5ba9d659dac', 'scope': 'profile email'}
# 200
# eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJGZHl5YkhKcHB0bTdMNnJ5d2Npd2Rlb1hsYktTVVcwY0NNYU5lRHAtZlZrIn0.....g4GRNPYvdaFEWyO_vsyUAeQQOkj7REKnN9587g6gCSOsHnF71aYllq5BJ3aV3G7e1dgnNPYyH_fpNuWyu31ICvNe96W3qXXintAsDjLwgvc1ghWchJzOK_vyCdhAh1HJATMMIhNNKedPAQtnmgP8itYfngfqJpctn_lPO58LRZJjfXx5gV6_vxmw4ZEYJ66yYHazJe3v9eHz_PglPfy-IaMsORqacYtfTrVMrga7xJ4JoegmznwamteimPd9KrtNg8ha39yIzAnR4mQZGGQ9VjW9rYe4LAzAUv4EH8rMtGHz9ZwoR90mag0dp5rmlNoMRG6bqI93KF0_m7js1ap6Gg

# %%
headers = {
    'content-type': 'application/json',
    'Authorization': 'Bearer %s'%token, 
}

# %%
singledata = {
    "name":"GURIYA K", 
    "father":"S M Arya",
    "mother":"S M Arya",
    "grades": "a",
    "rollNumber": "2224300010",
    "dob": "1998-09-20",
    "gender": "F",
    "mobile": "9087363655",
    "email": "kumarpawans@gmail.com",
    "qualification":"DIPLOMA IN GENERAL NURSING and MIDWIFERY",
    "enrollmentNumber":"2210254300054",
    "examYear":"2022",
    "dated": "1922-12-29",
    "barCode": "123456",
    "credType":"Registration",
    "yearsOfTheCourse":[{
        "courseYear":"First Year",
        "examYear":"2020",
        "examMonth":"March",
        "result":"PASS",
        "totalMarksObtained":"426",
        "totalMarksObtainedInWord":"Four hundred and Twenty Six",
        "maxTotal":"500",
    "subject":[{"name":"COMMUNITY HEALTH NURSING","max-ext":"75","max-int":"25","obt-ext":"46","obt-int":"20","total":"66"},
    {"name":"HEALTH PROMOTION","max-ext":"75","max-int":"25","obt-ext":"40","obt-int":"19","total":"59"}]
    },
    {
        "courseYear":"Second Year",
        "examYear":"2021",
        "examMonth":"March",
        "result":"PASS",
        "totalMarksObtained":"426",
        "totalMarksObtainedInWord":"Four hundred and Twenty Six",
        "maxTotal":"500",
    "subject":[{"name":"COMMUNITY HEALTH NURSING","max-ext":"75","max-int":"25","obt-ext":"46","obt-int":"20","total":"66"},
    {"name":"HEALTH PROMOTION","max-ext":"75","max-int":"25","obt-ext":"40","obt-int":"19","total":"66"}]
    },
    {
        "courseYear":"Final Year",
        "examYear":"2022",
        "examMonth":"March",
        "result":"PASS",
        "totalMarksObtained":"426",
        "totalMarksObtainedInWord":"Four hundred and Twenty Six",
        "maxTotal":"500",
    "subject":[{"name":"COMMUNITY HEALTH NURSING","max-ext":"75","max-int":"25","obt-ext":"46","obt-int":"20","total":"66"},
    {"name":"HEALTH PROMOTION","max-ext":"75","max-int":"25","obt-ext":"40","obt-int":"19","total":"66"}]
    }]

}

# %%
userId =str(random.randint(1e10,1e11))



resp = requests.post("%s%s"%(base_url, '/api/v1/StudentMarksSheet'), headers=headers, json=singledata)
print(resp)
#assert resp.status_code == 200 or print (resp.json())
#idx = resp.json()["result"][entity_name]["osid"]
# Out:
# <Response [200]>

# %%
resp.json()
# Out:
# {'id': 'sunbird-rc.registry.create',
#  'ver': '1.0',
#  'ets': 1688119619218,
#  'params': {'resmsgid': '',
#   'msgid': '2a85fa5a-bace-4e0d-af8c-48310997e20c',
#   'err': '',
#   'status': 'SUCCESSFUL',
#   'errmsg': ''},
#  'responseCode': 'OK',
#  'result': {'StudentMarksSheet': {'osid': '1-7cdff784-0c64-4678-96ff-ce7e6d21e5d4'}}}

# %%
print(resp.json())
resp.status_code, userId
# Out:
# {'id': 'sunbird-rc.registry.create', 'ver': '1.0', 'ets': 1688119619218, 'params': {'resmsgid': '', 'msgid': '2a85fa5a-bace-4e0d-af8c-48310997e20c', 'err': '', 'status': 'SUCCESSFUL', 'errmsg': ''}, 'responseCode': 'OK', 'result': {'StudentMarksSheet': {'osid': '1-7cdff784-0c64-4678-96ff-ce7e6d21e5d4'}}}
# (200, '74541046421')

# %% [markdown]
# # generate certificate

# %%
idx="1-7cdff784-0c64-4678-96ff-ce7e6d21e5d4"
resp = requests.get("%s/api/v1/%s/%s"%(base_url, "StudentMarksSheet", idx), headers={"Accept":"application/pdf", 'Authorization': 'Bearer %s'%token, "template": "https://raw.githubusercontent.com/kumarpawantarento/templates/main/nursingANM.html"})
resp.status_code, resp.content
print (resp.content)
# Out:
# b'%PDF-1.4\n%\xd3\xeb\xe9\xe1\n1 0 obj\n<</Creator (Chromium)\n/Producer (Skia/PDF m102)\n/CreationDate (D:20230630101050+00\'00\')\n/ModDate (D:20230630101050+00\'00\')>>\nendobj\n3 0 obj\n<</ca 1\n/BM /Normal>>\nendobj\n4 0 obj\n<</CA 1\n/ca 1\n/LC 0\n/LJ 0\n/LW 1\n/ML 4\n/SA true\n/BM /Normal>>\nendobj\n7 0 obj\n<</CA 1\n/ca 1\n/LC 0\n/LJ 0\n/LW 2\n/ML 4\n/SA true\n/BM /Normal>>\nendobj\n8 0 obj\n<</Type /XObject\n/Subtype /Image\n/Width 811\n/Height 858\n/ColorSpace /DeviceRGB\n/BitsPerComponent 8\n/Filter /DCTDecode\n/ColorTransform 0\n/Length 16384>> stream\n\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x